# %% [markdown]
# ### 4x4
#
#
# #### Matrices
#
# matrix10 =
# $\begin{bmatrix}
#     5 & 2 & 6 & 1 \\
#     0 & 6 & 2 & 0 \\
#     3 & 8 & 1 & 4 \\
#     1 & 8 & 5 & 6
# \end{bmatrix}$
#
# matrix20 =
# $\begin{bmatrix}
#     7 & 5 & 8 & 0 \\
#     1 & 8 & 2 & 6 \\
#     9 & 4 & 3 & 8 \\
#     5 & 3 & 7 & 9
# \end{bmatrix}$
#
#
# #### Addition
#
# matrix30 = matrix10 + matrix20 =
# $\begin{bmatrix}
#     5 & 2 & 6 & 1 \\
#     0 & 6 & 2 & 0 \\
#     3 & 8 & 1 & 4 \\
#     1 & 8 & 5 & 6
# \end{bmatrix}$
# +
# $\begin{bmatrix}
#     7 & 5 & 8 & 0 \\
#     1 & 8 & 2 & 6 \\
#     9 & 4 & 3 & 8 \\
#     5 & 3 & 7 & 9
# \end{bmatrix}$
# =
# $\begin{bmatrix}
#     5+7 & 2+5 & 6+8 & 1+0 \\
#     0+1 & 6+8 & 2+2 & 0+6 \\
#     3+9 & 8+4 & 1+3 & 4+8 \\
#     1+5 & 8+3 & 5+7 & 6+9
# \end{bmatrix}$
# =
# $\begin{bmatrix}
#     12 & 7 & 14 & 1  \\
#     1 & 14 & 4 & 6   \\
#     12 & 12 & 4 & 12 \\
#     6 & 11 & 12 & 15
# \end{bmatrix}$
#
#
# #### Substraction
#
# matrix40 = matrix10 - matrix20 =
# $\begin{bmatrix}
#     5 & 2 & 6 & 1 \\
#     0 & 6 & 2 & 0 \\
#     3 & 8 & 1 & 4 \\
#     1 & 8 & 5 & 6
# \end{bmatrix}$
# -
# $\begin{bmatrix}
#     7 & 5 & 8 & 0 \\
#     1 & 8 & 2 & 6 \\
#     9 & 4 & 3 & 8 \\
#     5 & 3 & 7 & 9
# \end{bmatrix}$
# =
# $\begin{bmatrix}
#     5-7 & 2-5 & 6-8 & 1-0 \\
#     0-1 & 6-8 & 2-2 & 0-6 \\
#     3-9 & 8-4 & 1-3 & 4-8 \\
#     1-5 & 8-3 & 5-7 & 6-9
# \end{bmatrix}$
# =
# $\begin{bmatrix}
#     -2 & -3 & -2 & 1 \\
#     -1 & -2 & 0 & -6 \\
#     -6 & 4 & -2 & -4 \\
#     -4 & 5 & -2 & -3
# \end{bmatrix}$
#
#
#
# #### Multiplication
#
# matrix50 = matrix10 x matrix20 =
# $\begin{bmatrix}
#     5 & 2 & 6 & 1 \\
#     0 & 6 & 2 & 0 \\
#     3 & 8 & 1 & 4 \\
#     1 & 8 & 5 & 6
# \end{bmatrix}$
# x
# $\begin{bmatrix}
#     7 & 5 & 8 & 0 \\
#     1 & 8 & 2 & 6 \\
#     9 & 4 & 3 & 8 \\
#     5 & 3 & 7 & 9
# \end{bmatrix}$
#
# =
# $\begin{bmatrix}
#     (5\times7 + 2\times1 + 6\times9 + 1\times5) & (5\times5 + 2\times8 + 6\times4 + 1\times3) & (5\times8 + 2\times2 + 6\times3 + 1\times7) & (5\times0 + 2\times6 + 6\times8 + 1\times9) \\
#     (0\times7 + 6\times1 + 2\times9 + 0\times5) & (0\times5 + 6\times8 + 2\times4 + 0\times3) & (0\times8 + 6\times2 + 2\times3 + 0\times7) & (0\times0 + 6\times6 + 2\times8 + 0\times9) \\
#     (3\times7 + 8\times1 + 1\times9 + 4\times5) & (3\times5 + 8\times8 + 1\times4 + 4\times3) & (3\times8 + 8\times2 + 1\times3 + 4\times7) & (3\times0 + 8\times6 + 1\times8 + 4\times9) \\
#     (1\times7 + 8\times1 + 5\times9 + 6\times5) & (1\times5 + 8\times8 + 5\times4 + 6\times6) & (1\times8 + 8\times2 + 5\times3 + 6\times8) & (1\times0 + 8\times6 + 5\times8 + 6\times9)
# \end{bmatrix}$
#
# =
# $\begin{bmatrix}
#     (35 + 2 + 54 + 5) & (25 + 16 + 24 + 3) & (40 + 4 + 18 + 7) & (0 + 12 + 48 + 9) \\
#     (0 + 6 + 18 + 0) & (0 + 48 + 8 + 0) & (0 + 12 + 6 + 0) & (0 + 36 + 16 + 0) \\
#     (21 + 8 + 9 + 20) & (15 + 64 + 4 + 12) & (24 + 16 + 3 + 28) & (0 + 48 + 8 + 36) \\
#     (7 + 8 + 45 + 30) & (5 + 64 + 20 + 18) & (8 + 16 + 15 + 42) & (0 + 48 + 40 + 54)
# \end{bmatrix}$
#
# matrix50 =
# $\begin{bmatrix}
#     96 & 68  & 69 & 69 \\
#     24 & 56  & 18 & 52 \\
#     58 & 95  & 71 & 92 \\
#     90 & 107 & 81 & 142
# \end{bmatrix}$
#
# #### Multiplication by a vector
#
# vector1 =
# $\begin{bmatrix}
#     5 \\
#     -2 \\
#     3 \\
#     1
# \end{bmatrix}$
#
# matrix60 = matrix10 x vector1 =
# $\begin{bmatrix}
#     5 & 2 & 6 & 1 \\
#     0 & 6 & 2 & 0 \\
#     3 & 8 & 1 & 4 \\
#     1 & 8 & 5 & 6
# \end{bmatrix}$
# x
# $\begin{bmatrix}
#     5  \\
#     -2 \\
#     3  \\
#     1
# \end{bmatrix}$
#
# =
# $\begin{bmatrix}
#     5\times5 + 2\times-2 + 6\times3 + 1\times1 \\
#     0\times5 + 6\times-2 + 2\times3 + 0\times1 \\
#     3\times5 + 8\times-2 + 1\times3 + 4\times1 \\
#     1\times5 + 8\times-2 + 5\times3 + 6\times1
# \end{bmatrix}$
#
# =
# $\begin{bmatrix}
#     25 - 4  + 18 + 1 \\
#      0 - 12 + 6 + 0  \\
#     15 - 16 + 3 + 4  \\
#      5 - 16 + 15 + 6
# \end{bmatrix}$
#
# matrix60 =
# $\begin{bmatrix}
#     40 \\
#     -6 \\
#     6  \\
#     10
# \end{bmatrix}$
